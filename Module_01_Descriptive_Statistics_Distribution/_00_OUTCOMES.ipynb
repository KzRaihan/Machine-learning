# %% [markdown]
# ## Topic: Statistics and Mathematics for Ml

# %% [markdown]
# ### OUTCOMES
# - 1. Introduction of Statistics for Ml
#
# - 2. Measure of central tendency
#
# - 3. Measure of Dispersion
#
# - 4. Measure of Position

# %% [markdown]
# 1. What is the middle value in a sorted dataset called?
#
# 2. The difference between the highest and lowest values in a dataset is called?
#
# 3. Which measure of spread is based on the middle 50% of the data?
#
# 4. What does a large standard deviation indicate about the data?
#
# 5. The value that appears most frequently in a dataset is called?
#
# 6. A z-score of 0 tells you that the data point is:
#
#
# 7. A student scores in the 88th percentile on a national exam. This means that:
#
#
# 8. Using the IQR method, what is the upper fence for outliers if Q1 = 10 and Q3 = 20?
#
# 9. A dataset has a mean of 50. If every value in the dataset is multiplied by 2 and then increased by 5, what is the new mean?
#
# 10. A dataset has the following five-number summary: {12, 18, 20, 28, 35}. What is the value of the lower fence for detecting outliers?
