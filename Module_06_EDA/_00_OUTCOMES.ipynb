# %% [markdown]
# ## Topic: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### OUTCOMES
#
# - 1. EDA introduction
#
# - 2. Heart Failure Prediction Project Only EDA
#
#     - Understanding Data Distributions, correlatoins and patterns.
#     - Visualizing data with Histrograms, boxplot
#     - identifying data imbalance

# %% [markdown]
# 1. Which plot is best suited for understanding the distribution shape of a numerical feature?
#
# 2. What does a boxplot primarily help identify?
#
# 3. Which plot is most useful for detecting linear relationships between two numerical variables?
# - Bar chart
# - Boxplot
# - Scatter plot
# - Countplot
#
# 4. What does a correlation heatmap help analyze?
# - Distribution of categories
# - Strength of liner relationships between numerical features
#
# 5. What does a highly imbalanced target variable indicate?
# - Serious overfitting
# - Need for resampling or class weighting
#
# 6. Which EDA step helps check whether data types and ranges are reasonable?
#
# - Correlation heatmap
# - describe() and info()
# - pairplot
# - countplot
#
# 7. Which visualization is suitable for checking distribution differences of a numerical feature across a target (0/1)?
# - Boxplot grouped by target
# - Histogram without grouping
# - bar chart
# - line plot
#
# 8. Pairplot is useful for which purpose?
#
# - exploring pariwise relationships among multiple numerical variables
#
# - encoding categorical variables
#
# - Detecting class imbalance
#
# 9. Which of the following is the BEST first step before any visualization?
#
# - Perform normalization
# - convert all categorical variables
# - inspect shape, data types, and missing values
#
# 10. What is the main purpose of exploring categorical feature frequencies?
#
# - To identify outliers
# - To check if some categories have very few samples
#
# - To detect liner correlation
#
# - To scale the data

# %% [markdown]
# 1. Which method is commonly used to fill missing numerical values?
#
#
# 2. Which technique converts categorical labels into numbers like 0, 1, 2?
#
# - Standardization
# - Label Encoding
#
# 3. Scaling কোন কাজের জন্য করা হয়?
#
# 4. Which method is used to handle outliers effectively?
#
# 5. Polynomial Features কেন ব্যবহার করা হয়?
#
# 6. One-Hot Encoding কোন ধরণের ডেটার জন্য ব্যবহৃত হয়?
#
# - Numerical
# - Categorical(non-ordinal)
#
# 7. Normalization সাধারণত কোন ক্ষেত্রে ব্যবহৃত হয়?
#
#
#
# 7-6 Normalization and Scaling Part 1
# 7-7 Normalization and Scaling Part 2
#
# for specific:
# X_train_std = scalar_sd.fit_transform(X_train)
# X_test_std = scalar_sd.transform(X_train)
#
# this two lines work properly
