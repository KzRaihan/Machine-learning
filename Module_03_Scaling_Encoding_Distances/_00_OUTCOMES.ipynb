# %% [markdown]
# ## Topic: Scaling, Encoding and Distances

# %% [markdown]
# ### OUTCOMES
#
# - 1. Scaling and It's Need
#
# - 2. Encoding and Apply
#
# - 3. Distance Measure

# %% [markdown]
# 1. Which scaling technique transforms data to have a mean of 0 and standard deviation of 1?
#
#
# 2. Which scaling method rescales values within a fixed range, usually [0,1]?
#
# 3. Which scaling method is least affected by outliers?
#
# 4. Which distance metric calculates the shortest straight line between two points?
#
# 5. Which distance metric sums the absolute differences of coordinates?
#
# 6. What type of variable has a natural order or ranking?
#
#
# 7. Which encoding is best for nominal categorical variables?
#
# 8. Which encoding method assigns integer values based on rank order?
#
# 9. What is the main difference between Euclidean and Manhattan distance?

# %% [markdown]
# Module_next:
#
# 1. How does Machine Learning work?
#
# 2. Which type of Machine Learning uses labeled datasets to train algorithms?
#
# 3. An algorithm that groups customers based on their purchasing behavior without any pre-defined categories is an example of:
#
# 4. A robot learning through rewards and penalties is an example of:
#
#
# 5. In predicting house prices, ‘number of bedrooms’ and ‘square footage’ are:
# - lables
# - Models
# - Featues
# - output
#
# 6. Teaching an ML model by showing it data is called:
# - Testing
# - Training
# - proprocessing
#
#
# 7. A model’s ability to perform well on unseen data is known as:
#
# 8. Handling missing values and scaling numerical data occurs in:
# - Data Collection
# - Data preporocesing
# - model training
# - model evalution
#
# 9. If a model performs well on training data but poorly on test data, it is an example of:
# - Underfiting
# - overfittin
# -
#
# 10. Your model shows poor performance on both training data and new test data. It seems too basic to capture the patterns in the dataset. This problem is known as:
#
# - overfiting
# - pefect fiting
# - generalization
# - Underfition.
