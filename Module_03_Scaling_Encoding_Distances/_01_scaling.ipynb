# %% [markdown]
# ## Topic: Scaling and It's Need

# %% [markdown]
# ### OUTCOMES
#
# - 0. Introduction of Pattern Recognition
#
# - 1. Why Size can Misleading
#
# - 2. Definition of Scaling
#
# - 3. Why need scaling
#
# - 4. Types of Scaling
#
# - 5. After Scaling how look like data.

# %% [markdown]
# ### 0. Introduction of Pattern Recognition

# %% [markdown]
# - Definition of Pattern Recognition:
#     - The study of how machine can
#         - i. Observe the enviroment.
#
#         - ii. Learn the characterize the object of interest.
#
#         - iii. Make sound and responable decisions about the category of the pattern.

# %% [markdown]
# ### 1. Why Size can Misleading

# %% [markdown]
# - Computer work with numerical data
# - Any featues contain the bigger numbers  then computer priority those column or (dominate the smaller featues.
# )
# - And learn pattern of those bigger featues and take decision based on bigger featues (most Priority)
#
# - so, overall
#     - if the featues size of bigger then model priority those featues to learn and take decision.
#     - in this case, the model decision is not accurate.
#     - So, the model decision is misleading.

# %% [markdown]
# ### 2. Definition of Scaling

# %% [markdown]
# - Scaling give each feature an equal opportunity to contribute to the learning model.

# %% [markdown]
# ### 3. Why need scaling

# %% [markdown]
# - model can fair comparsion, better performance.

# %% [markdown]
# ### 4. Types of Scaling

# %% [markdown]
# - 1. Z-score Scaling.
#
# - 2. Min-max Scalling.
#
# - 3. Robust scaling.

# %% [markdown]
# ### 5. After Scaling how look like data.

# %% [markdown]
# - After scaling data are a particalur range in between 0 to 1.
